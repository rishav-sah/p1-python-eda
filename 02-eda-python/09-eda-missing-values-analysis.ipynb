# %% [markdown]
# ## Missing Value Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "../data/Visa_Predection_Dataset.csv"
df_visa = pd.read_csv(file_path)
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
dict1 = {
    "Name": ["Tom", "Harry", "Jack", np.nan],
    "Age": [30, 31, np.nan, 33],
    "City": [np.nan, "Miami", "LA", "SF"]
}

df = pd.DataFrame(dict1)
df
# Out:
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack   NaN     LA
# 3    NaN  33.0     SF

# %% [markdown]
# #### Method-1:
# Fill with a random number to all null values

# %%
df.isnull() # returns df consisting of true and false values
# Out:
#     Name    Age   City
# 0  False  False   True
# 1  False  False  False
# 2  False   True  False
# 3   True  False  False

# %%
df_visa.isna().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# #### $fillna$

# %%
df.fillna(40, inplace=True) # puts 40 in the df

# %%
df
# Out:
#     Name   Age   City
# 0    Tom  30.0     40
# 1  Harry  31.0  Miami
# 2   Jack  40.0     LA
# 3     40  33.0     SF

# %%
df
# Out:
#     Name   Age   City
# 0    Tom  30.0     40
# 1  Harry  31.0  Miami
# 2   Jack  40.0     LA
# 3     40  33.0     SF

# %% [markdown]
# #### Method 2
# - Fill the value using column wise

# %%
df.fillna({"Name": "Julian"}, inplace=True)
df.fillna({"Age": "32"}, inplace=True)
df.fillna({"City": "Atlanta"}, inplace=True)

# %%
df
# Out:
#     Name   Age   City
# 0    Tom  30.0     40
# 1  Harry  31.0  Miami
# 2   Jack  40.0     LA
# 3     40  33.0     SF

# %%
df.dtypes
# Out:
# Name     object
# Age     float64
# City     object
# dtype: object

# %% [markdown]
# #### Method 3
#
# - other ways for imputation of missing values instead of mean, median mode.
# - pad
# - bfill
# - backfill
# - ffill

# %%
print("----------------- original -----------------")
print(df)

print("----------------- pad -----------------")
print(df.pad())

print("----------------- ffill -----------------")
print(df.ffill())

print("----------------- bfill -----------------")
print(df.bfill())

print("----------------- backfill -----------------")
print(df.backfill())
# Out:
# ----------------- original -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack   NaN     LA
# 3    NaN  33.0     SF
# ----------------- pad -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack  31.0     LA
# 3   Jack  33.0     SF
# ----------------- ffill -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack  31.0     LA
# 3   Jack  33.0     SF
# ----------------- bfill -----------------
#     Name   Age   City
# 0    Tom  30.0  Miami
# 1  Harry  31.0  Miami
# 2   Jack  33.0     LA
# 3    NaN  33.0     SF
# ----------------- backfill -----------------
#     Name   Age   City
# 0    Tom  30.0  Miami
# 1  Harry  31.0  Miami
# 2   Jack  33.0     LA
# 3    NaN  33.0     SF
# /var/folders/yx/1kmpf_qx1yj6fg99qy8n7m840000gn/T/ipykernel_45638/3570760506.py:5: FutureWarning: DataFrame.pad/Series.pad is deprecated. Use DataFrame.ffill/Series.ffill instead
#   print(df.pad())
# /var/folders/yx/1kmpf_qx1yj6fg99qy8n7m840000gn/T/ipykernel_45638/3570760506.py:14: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   print(df.backfill())

# %%
print("----------------- original -----------------")
print(df)

print("----------------- pad -----------------")
print(df.pad(axis=1))

print("----------------- ffill -----------------")
print(df.ffill(axis=1))

print("----------------- bfill -----------------")
print(df.bfill(axis=1))

print("----------------- backfill -----------------")
print(df.backfill(axis=1))
# Out:
# ----------------- original -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack   NaN     LA
# 3    NaN  33.0     SF
# ----------------- pad -----------------
#     Name   Age   City
# 0    Tom  30.0   30.0
# 1  Harry  31.0  Miami
# 2   Jack  Jack     LA
# 3    NaN  33.0     SF
# ----------------- ffill -----------------
#     Name   Age   City
# 0    Tom  30.0   30.0
# 1  Harry  31.0  Miami
# 2   Jack  Jack     LA
# 3    NaN  33.0     SF
# ----------------- bfill -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack    LA     LA
# 3   33.0  33.0     SF
# ----------------- backfill -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack    LA     LA
# 3   33.0  33.0     SF
# /var/folders/yx/1kmpf_qx1yj6fg99qy8n7m840000gn/T/ipykernel_45638/2608928205.py:5: FutureWarning: DataFrame.pad/Series.pad is deprecated. Use DataFrame.ffill/Series.ffill instead
#   print(df.pad(axis=1))
# /var/folders/yx/1kmpf_qx1yj6fg99qy8n7m840000gn/T/ipykernel_45638/2608928205.py:14: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   print(df.backfill(axis=1))

# %%
print("----------------- original -----------------")
print(df)

print("----------------- pad -----------------")
print(df.pad(axis=0))

print("----------------- ffill -----------------")
print(df.ffill(axis=0))

print("----------------- bfill -----------------")
print(df.bfill(axis=0))

print("----------------- backfill -----------------")
print(df.backfill(axis=0))
# Out:
# ----------------- original -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack   NaN     LA
# 3    NaN  33.0     SF
# ----------------- pad -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack  31.0     LA
# 3   Jack  33.0     SF
# ----------------- bfill -----------------
#     Name   Age   City
# 0    Tom  30.0  Miami
# 1  Harry  31.0  Miami
# 2   Jack  33.0     LA
# 3    NaN  33.0     SF
# ----------------- backfill -----------------
#     Name   Age   City
# 0    Tom  30.0  Miami
# 1  Harry  31.0  Miami
# 2   Jack  33.0     LA
# 3    NaN  33.0     SF
# ----------------- ffill -----------------
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack  31.0     LA
# 3   Jack  33.0     SF
# /var/folders/yx/1kmpf_qx1yj6fg99qy8n7m840000gn/T/ipykernel_45638/1527813652.py:5: FutureWarning: DataFrame.pad/Series.pad is deprecated. Use DataFrame.ffill/Series.ffill instead
#   print(df.pad(axis=0))
# /var/folders/yx/1kmpf_qx1yj6fg99qy8n7m840000gn/T/ipykernel_45638/1527813652.py:11: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   print(df.backfill(axis=0))

# %% [markdown]
# #### Method 4: Mean, Median, Mode

# %%
df
# Out:
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack   NaN     LA
# 3    NaN  33.0     SF

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    30.000000
# 1    31.000000
# 2    31.333333
# 3    33.000000
# Name: Age, dtype: float64

# %%
df.fillna({"Age": df["Age"].mean().round(2)})
# Out:
#     Name    Age   City
# 0    Tom  30.00    NaN
# 1  Harry  31.00  Miami
# 2   Jack  31.33     LA
# 3    NaN  33.00     SF

# %%
df.fillna({"Age": df["Age"].median().round(2)})
# Out:
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack  31.0     LA
# 3    NaN  33.0     SF

# %%
df.fillna({"Age": df["Age"].mode().round(2)})
# Out:
#     Name   Age   City
# 0    Tom  30.0    NaN
# 1  Harry  31.0  Miami
# 2   Jack  33.0     LA
# 3    NaN  33.0     SF
