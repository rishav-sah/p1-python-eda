# %% [markdown]
# ### Packages
#
# #### ************** EDA **************
#
# 1. Pandas: Dataframe analysis
# 2. Numpy: Numerical python / Number python
# 3. Matplotlib: plot
# 4. Seaborn: plot
# 5. plotly: plot
# 6. bokhe: plot
#
# #### *********************** ML **************
# 7. scikit-learn: sklearn
#
# #### DL
# 8. tensorflow
# 9. keras
# 10. pytorch
# 11. cv: computer vision
#
# #### NLP
# 12. NLTK
# 13. Scipy
#
# #### Generative AI
# 14) chatgpt: OpenAI
# 15) makersuite: google generative ai
# 16) Amazon Q package
#
# #### Hugging face transformer (BERT)
# 17) Transformers
#
# #### Other
# random
# math
# os
# sys
# time
#
# #### Azure ML
# Azure packages
# gcp packages
# aws sage maker

# %%
#### Step 1: Import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#### Step 2: Read the data (Visa Dataset)
# file location
# file name
# file extension
visa_dataset = "../data/Visa_Predection_Dataset.csv"
df_visa = pd.read_csv(visa_dataset)

df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank_dataset = "../data/bank.csv"
df_bank = pd.read_csv(bank_dataset, sep=";")
df_bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# Step 3: Create a dataframe using list

list1 = ["Tom", "Dick", "Harry"]
list2 = [31, 32, 33]
cols = ["name", "age"]
names = pd.DataFrame(zip(list1, list2), columns=cols)

# %%
# Step 4: How to save the dataframe in your local
# what is your data frame: names
output_path = "../data/names1.csv"
names.to_csv(output_path, index=False) # index=False (it will not create extra column as index
print(f"saved to {output_path}")
# Out:
# saved to ../data/names1.csv

# %%
df_names = pd.read_csv("../data/names.csv")
df_names1 = pd.read_csv("../data/names1.csv")
print(df_names)
print(df_names1)
# Out:
#    Unnamed: 0   name  age
# 0           0    Tom   31
# 1           1   Dick   32
# 2           2  Harry   33
#     name  age
# 0    Tom   31
# 1   Dick   32
# 2  Harry   33

# %%
# Step 5: Adding a new column to existing dataframe
# what is the name of your dataframe
# what is the name of the column we need to add: city
# how many rows are in the original data
# what is your new data = ["Miami", "NY", "Los Angeles"]

names["city"] = ["Miami", "NY", "Los Angeles"]

# %%
print(names)
# Out:
#     name  age         city
# 0    Tom   31        Miami
# 1   Dick   32           NY
# 2  Harry   33  Los Angeles

# %%
names["id"]=[1, 2, 3, 4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 names["id"]=[1, 2, 3, 4]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
# ...

# %%
# Step 6: How to delete the column

# %%
# what is your dataframe name
# I want to drop column
############### Axis ##############
#### axis = 1 ====== columns
#### axis = 0 ====== rows
# what is the name of the column: city

####### inplace ########
# when you're dropping the column that means we're modifying the table
# the dataframe should be override or we want to create a new data frame

# inplace = True : data will be overwrite

# %%
names.drop("city", axis=1, inplace=True)

# %%
names
# Out:
#     name  age
# 0    Tom   31
# 1   Dick   32
# 2  Harry   33

# %%
6

# %%
# How to create dataframe using dictionary

dict1 = {
    "names": ["Tom", "Dick", "Harry"],
    "age": [30, 31, 32]
}

# keys automatically becomes column
# value becomes row

pd.DataFrame(dict1)
pd.DataFrame(dict1, columns=["A", "B"]) # can't modify the column names

pd.DataFrame(dict1, index=["A", "B", "C"])
# Out:
#    names  age
# A    Tom   30
# B   Dick   31
# C  Harry   32

# %%
# If list or dict is given, the dataframe must be created using them
