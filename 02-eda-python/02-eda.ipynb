# %%
# Install required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the data

visa_dataset = "../data/Visa_Predection_Dataset.csv"
df_visa = pd.read_csv(visa_dataset)

# %%
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Shape
type(df_visa) # pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
# Shape
df_visa.shape
# Out:
# (25480, 12)

# %%
print(f"The number of rows: {df_visa.shape[0]}")
print(f"The number of columns: {df_visa.shape[1]}")
# Out:
# The number of rows: 25480
# The number of columns: 12

# %%
#<package_name>.<method_name>()
df_visa.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #<package_name>.<method_name>()
# ----> 2 df_visa.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# we usually call the functions or methods that means ()
# not callable means remote the paranthesis

# %%
# Size
df_visa.size # no. of rows * now of columns
# Out:
# 305760

# %%
# retrieve Columns

df_visa.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df_visa.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_visa.columns.to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
# bound method means use the paranthesis

# dict() === to_dict()
# list() === to_list()

# %%
# dtypes
df_visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
# object means categorial column
# int64 and float64

type(df_visa.dtypes)
# Out:
# pandas.core.series.Series

# %%
df_visa.dtypes.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df_visa.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df_visa.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
type(df_visa.dtypes.values) # numpy n dimensions array
# Out:
# numpy.ndarray

# %%
dir(df_visa.dtypes)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
list1 = [1, 2, 3]
list1

[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
np.array([1,2,3])+np.array([4, 5, 6])
# Out:
# array([5, 7, 9])

# %% [raw]
# # array[] => numpy
# # index[] => pandas index
# # pandas.dataframe
# # pandas.series

# %%
# task 1: seperate categorial and numerical columns

# %%
df_visa_dict = df_visa.dtypes.to_dict()
df_visa_dict
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
# create two lists
df_visa_cat = []
df_visa_num = []
for key, value in df_visa_dict.items():
    print(f"{key}: {value}")
    if (value == "object"):
        df_visa_cat.append(key)
    else:
        df_visa_num.append(key)


print("The categorial columns (df_visa_cat):", df_visa_cat)
print("The numerical columns (df_visa_num):", df_visa_num)
# Out:
# case_id: object
# continent: object
# education_of_employee: object
# has_job_experience: object
# requires_job_training: object
# no_of_employees: int64
# yr_of_estab: int64
# region_of_employment: object
# prevailing_wage: float64
# unit_of_wage: object
# full_time_position: object
# case_status: object
# The categorial columns (df_visa_cat): ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# The numerical columns (df_visa_num): ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# better way - list comprehension

df_visa_cat = [key for key, value in df_visa_dict.items() if value == "object"]
df_visa_num = [key for key, value in df_visa_dict.items() if value == "int64"]

print("The categorical columns: ", df_visa_cat)
print("The categorical columns: ", df_visa_num)
# Out:
# The categorical columns:  ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# The categorical columns:  ['no_of_employees', 'yr_of_estab']

# %% [markdown]
# #### $head$

# %%
df_visa.head() # top 5 rows, default arg = 5
# starting index with 0
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df_visa.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# #### $tail$

# %%
df_visa.tail() # default last 5 rows, default args = 5
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# #### $take$

# %%
# retrieving specific rows
list1 = [100, 200, 300] # 100th row, 200th row, 300th row
df_visa.take(list1)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
list1 = [1, 2, 11]
df_visa.take(list1, axis=1)

# in python the index starts with 0
# 1 ====== 2nd column
# 2 ====== 3rd column
# 11 ===== 12th column

# default axis = 0
# Out:
#       continent education_of_employee case_status
# 0          Asia           High School      Denied
# 1          Asia              Master's   Certified
# 2          Asia            Bachelor's      Denied
# 3          Asia            Bachelor's      Denied
# 4        Africa              Master's   Certified
# ...         ...                   ...         ...
# 25475      Asia            Bachelor's   Certified
# 25476      Asia           High School   Certified
# 25477      Asia              Master's   Certified
# 25478      Asia              Master's   Certified
# 25479      Asia            Bachelor's   Certified
#
# [25480 rows x 3 columns]

# %%
list2 = [1, 2, 12] # 12th column not available in the dataframe. error code IndexError: indices are out-of-bounds
df_visa.take(list2, axis=1)

# %% [markdown]
# ##### $Task-2$

# %%
# Retrieving 150, 300, 450 rows from 5, 8 and 12

list1 = [150, 300, 450]
list2 = [4, 7, 11]

df_visa_temp = df_visa.take(list1, axis=0)
df_visa_final = df_visa_temp.take(list2, axis=1)
df_visa_final
# Out:
#     requires_job_training region_of_employment case_status
# 150                     N                 West      Denied
# 300                     N              Midwest   Certified
# 450                     Y                 West      Denied

# %%
df_visa.take([150, 300, 450], axis=0).take([5, 8, 11], axis=1) ## as both the methods returns the dataframe
df_visa.take([4, 7, 11], axis=1).take([150, 300, 450]) # works vice versa but better to decide the column first then the row
# Out:
#      no_of_employees  prevailing_wage case_status
# 150            50351         529.1105      Denied
# 300             3268      101371.2100   Certified
# 450             1543       78402.7200      Denied

# %% [markdown]
# #### iloc-loc

# %%
df_visa.iloc[<rows>.<columns>]
df_visa.iloc[start:end, start:end]

# %%
df_visa.iloc[50:54, 2:6]
# 50 rows 54
# 2 to 5
# Out:
#    education_of_employee has_job_experience requires_job_training  \
# 50            Bachelor's                  N                     N
# 51              Master's                  Y                     N
# 52            Bachelor's                  N                     N
# 53           High School                  Y                     N
#
#     no_of_employees
# 50              746
# 51             3129
# 52             1647
# 53             2438

# %%
df_visa.iloc[[100, 150, 200], [5, 8, 11]]
# Out:
#      no_of_employees  prevailing_wage case_status
# 100             2227       28243.7900   Certified
# 150            50351         529.1105      Denied
# 200             3282       74441.1100   Certified

# %%
# iloc disadvantages: will take only intetgers

df_visa.iloc[[100, 150, 200], "case_status"]

# %%
# to avoid this drawback we will go for loc

# list of rows
# list of columns
rows = [100, 200, 300]
cols = ["continent", "case_status"]
df_visa.loc[[100, 200, 300], ["case_status"]]
df_visa.loc[rows, cols]
# Out:
#     continent case_status
# 100      Asia   Certified
# 200      Asia   Certified
# 300      Asia   Certified

# %%
len(df_visa)
# Out:
# 25480

# %% [markdown]
# - shape
# - size
# - dtypes
# - columns
# - we separated cat & num col
# - head
# - tail
# - take
# - iloc
# - loc
# - len
# - isnull
# - info

# %% [markdown]
# #### Checking the missing values in the data
# - isnull : whether there are any missing values in the data
# - if any missing value: True
# - if no missing value: False

# %%
df_visa.isnull()
df_visa.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
df_visa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
df_visa.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000
