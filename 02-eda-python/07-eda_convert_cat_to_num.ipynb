# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "../data/Visa_Predection_Dataset.csv"
df_visa = pd.read_csv(file_path)
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #### Encoding
#
# - In ML models, the algorithms will be developed using mathematics
# - Math allows only number
# - so it is very important, we need to pass numerical data only
# - so we need to convert categorical data to numerical data
# - For that we have encoding methods
# - Encoding
#   - Label Encoder
#     - map method
#     - np.where
#     - LabelEncoder package from sklearn
#   - One-hot encoder
#     - pd.get_dummies()

# %% [markdown]
# #### Method 1: Map Method
#
# - Read any categorical column: case_status
# - check how many unique labels are there
# - create a dictionary with those unique labels as keys by providing a number as a value

# %%
df_visa['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
dict1 = {
    'Certified': 0,
    'Denied': 1
}
df_visa['case_status'].map(dict1)
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
# do we want a overwrite column
# or existed column

df_visa['case_status_num'] = df_visa['case_status'].map(dict1)

# %%
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df_visa.drop('case_status_num', 
             axis=1, 
             inplace=True
            )

# %%
df_visa['case_status'] = df_visa['case_status'].map(dict1)

# in the map method there's no inplace=True

# %%
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
list_of_continents = df_visa['continent'].unique()

# %%
dict1 = {}
a = 0
for i in list_of_continents:
    dict1[i] = a
    a = a + 1
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
df_visa['continent'] = df_visa['continent'].map(dict1)

# %%
df_visa
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# using dictionary comprehension
labels = df_visa['continent'].unique()
num = len(df_visa['continent'].unique())
dict1 = {
    labels[i]:i for i in range(num)
}
dict1
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
df_visa['continent'] = df_visa['continent'].map(dict1)

# %%
df_visa
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #### Method 2: $np.where()$

# %%
# Read the data again
# np.where is applicable for binary conditions
# applicable for two labels
# np.where(<condition>,<True_value>, <False_value>)
# For example case_status have two labels
# condition: <col_values> == 'Certified'
# True value: Replace all certified values with 0
# False value: Replace all denied values with 1

# %%
con = df_visa['case_status']=="Certified"
df_visa['case_status'] = np.where(con, 0, 1)
df_visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #### LabelEncoder
#
# - LabelEncoder is a method by sklearn
# - under sklearn we have sub modules
# - One of the submodule: preprocessing
# - Any sklearn packages we have only 3 steps
# - Step-1: Read the package
# - Step-2: Save the package
# - Step-3: Apply fit transform

# %%
# Step-1
from sklearn.preprocessing import LabelEncoder

# %%
import random
random.randint(10, 20)
# Out:
# 16

# %%
from random import randint
randint(10,20)
# Out:
# 12

# %%
# Step-2
le = LabelEncoder()

# Step-3
df_visa['case_status'] = le.fit_transform(df_visa['case_status'])

# %%
df_visa['continent'] = le.fit_transform(df_visa['continent'])

# %% [markdown]
# #### fit_transform

# %% [raw]
# fit_transform
#
# - Fit and Transform are two different definitions
#
# age
# 1
# 2
# 3
# 4
# 5
#
# new age: by adding each observation with the mean value: x+mean
# mean = 1+2+3+4+5/5 = 3 ==========> fit
#
# new_age ==========================> Transform
# 1+3
# 2+3
# 3+3
# 4+3
# 5+3
#
# - The labels are applied using alphabet order
# - But to recognize the applied label, we have to read the data manually.
# - we can use le.inverse_transform()

# %%
df_visa['continent'].unique()
# Out:
# array([1, 0, 3, 2, 5, 4])

# %%
le.inverse_transform(df_visa['continent'])
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %% [markdown]
# #### One Hot Encoder
#
# - one hot encoder means at a time only one will be ON(1/True), others are OFF(0/False)
# - Suppose case status has two unique labels
# - Certified and Denied
# - In one hot encoder it will create two new columns
# - like below
#
# | case_status |  certified  |  denied|
# |-------------|-------------|--------|
# | certified | 1 | 0 |
# | denied    | 0 | 0 |
#
# **Advantage**
#
# - One hot encoder new columns are orthogonal to each other
# - Orthogonality means 90 degrees phase shift
# - 90 degrees phase shift means perpendicular to each other
# - Perpendicular means independent to each other
# - Independent means no relation
# - It is very important property that is to avoid relation between variables
#
# **Drawbacks**
# - Assume that you we have 100 unique labels for a column
# - so it will create 100 new columns
# - To process 100 columns we require more memory, more time and more hardward resources.
# - This is called curse of dimensionality

# %% [markdown]
# $pd.get_dummies$

# %%
pd.get_dummies(df_visa, columns=['case_status'], dtype="int") # default dtype: True / False
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.get_dummies(df_visa, columns=['continent'], dtype="int")
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...
