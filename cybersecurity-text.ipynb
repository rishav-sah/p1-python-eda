# %%
import pandas as pd

# %%
file_path = "./data/cyber-attacks.dta"
df = pd.read_stata(file_path)

# %%
df.isnull().sum()
# Out:
# CYBERSECURITY_BREACH_KEY             0
# COMPANY_FKEY                         0
# BREACH_DISCLOSURE_DATE               0
# BREACH_START_DATE                  652
# BREACH_END_DATE                    828
# BREACH_AWARE_DATE                  652
# NUMBER_OF_RECORDS_LOST             852
# BREACH_COST                        835
# BREACH_COST_USD                   1154
# BREACH_INFORMATION_TYPE              0
# TYPE_OF_ATTACK_LIST                  0
# INFORMATION_ACCESSED_LIST            0
# AUDITOR_FKEY_DURING_EVENT_DATE      15
# AUDITOR_NAME_DURING_EVENT_DATE       0
# AUDITOR_PCAOB_DURING_EVENT           0
# NAME                                 0
# BEST_EDGAR_TICKER                    0
# ISIN                                 0
# CUSIP_NUMBER                         0
# COMPANY_KEY                          0
# FISCAL_YE                            0
# dtype: int64

# %%
df.head(10)
# Out:
#    CYBERSECURITY_BREACH_KEY COMPANY_FKEY BREACH_DISCLOSURE_DATE  \
# 0                     551.0   0000003116             2015-06-18
# 1                     814.0   0000003453             2020-11-24
# 2                     820.0   0000004457             2017-12-11
# 3                    1155.0   0000004457             2022-09-09
# 4                     384.0   0000004962             2018-03-20
# 5                     397.0   0000004977             2017-03-16
# 6                     309.0   0000004977             2018-09-28
# 7                     222.0   0000005513             2019-01-18
# 8                      78.0   0000005513             2019-12-20
# 9                     215.0   0000005513             2020-10-02
#
#   BREACH_START_DATE BREACH_END_DATE BREACH_AWARE_DATE  NUMBER_OF_RECORDS_LOST  \
# 0               NaT             NaT               NaT                 50000.0
# 1               NaT             NaT        2020-10-14                     NaN
# ...

# %%
df.columns
# Out:
# Index(['CYBERSECURITY_BREACH_KEY', 'COMPANY_FKEY', 'BREACH_DISCLOSURE_DATE',
#        'BREACH_START_DATE', 'BREACH_END_DATE', 'BREACH_AWARE_DATE',
#        'NUMBER_OF_RECORDS_LOST', 'BREACH_COST', 'BREACH_COST_USD',
#        'BREACH_INFORMATION_TYPE', 'TYPE_OF_ATTACK_LIST',
#        'INFORMATION_ACCESSED_LIST', 'AUDITOR_FKEY_DURING_EVENT_DATE',
#        'AUDITOR_NAME_DURING_EVENT_DATE', 'AUDITOR_PCAOB_DURING_EVENT', 'NAME',
#        'BEST_EDGAR_TICKER', 'ISIN', 'CUSIP_NUMBER', 'COMPANY_KEY',
#        'FISCAL_YE'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 21
